# %% [markdown]
# <a href="https://colab.research.google.com/github/vijishmadhavan/App/blob/master/Aesthetic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Download Model

import urllib.request
from fastai.vision import *
import warnings
warnings.filterwarnings("ignore")
MODEL_URL = "https://www.dropbox.com/s/3s9x9zllbegpilx/Aesthetic.pkl?dl=1"
urllib.request.urlretrieve(MODEL_URL, "Aesthetic.pkl")
path = Path(".")
learn=load_learner(path, 'Aesthetic.pkl')

# %% [markdown]
# Right-click and copy image address from photos available online.
#
# Some examples from Google to try!!
#
# Bad Portrait Photography
# https://rb.gy/yll0wg
#
# Bad Photography
# https://rb.gy/eb1c2t
#
# Good Photography
# https://rb.gy/r1ucz5

# %%
url = 'https://www.howtogeek.com/wp-content/uploads/2021/03/badflash.jpg?trim=1,1&bg-color=000&pad=1,1' #@param {type:"string"}

response = requests.get(url)
img1 = PIL.Image.open(BytesIO(response.content)).convert("RGB")
img = img1.save("test.jpg")
img = open_image('test.jpg')
img
# Out:
# Image (3, 488, 650)

# %%
  #@title Predict

  pred_class,_,probs = learn.predict(img)

  pred_class.obj
# Out:
# 'Low Aesthetic'
